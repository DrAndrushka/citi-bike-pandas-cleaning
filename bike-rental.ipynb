# %% [markdown]
# ### There are CSV files containing Citi Bike data
#
# Renamed columns to a consistent snake_case schema
#
# Converted start_time/stop_time to datetime64[ns] and computed trip_duration as timedelta64[ns]
#
# Cleaned categorical variables (mapped gender codes to labels, preserved true missing values)
#
# Added boolean flags for missing user_type, birth_year, and gender, plus a combined “bad/missing demographics” flag
#
# Created an age feature (ride-year minus birth_year) and flagged implausible birth years (e.g., <= 1900)

# %%
# ✅ import all the cool stuff we are working with
import pandas as pd
import glob
import numpy as np

# %%
# ✅ Loading and concatenating the Citi Bike CSVs
bike_files = glob.glob('data/JC-*-citibike-tripdata.csv')

df_list = []
for filename in bike_files:
    data = pd.read_csv(filename)
    df_list.append(data)
    bikes = pd.concat(df_list)

bikes = bikes.reset_index().drop(columns='index')

# ✅ Getting a sense of the data
bikes.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.050656    24647  Subscriber      1964.0       2
# 1             -74.047727    24605  Subscriber      1962.0       1
# 2             -74.047727    24689  Subscriber      1962.0       2
# 3             -74.044247    24693  Subscriber      1984.0       1
# 4             -74.051789    24573    Customer         NaN       0

# %%
# ✅ check info to understand how much data I have to deal with
# bikes.info()

# %%
# ✅ show how much missing values there are
bikes.isna().sum()
# Out:
# Trip Duration                  0
# Start Time                     0
# Stop Time                      0
# Start Station ID               0
# Start Station Name             0
# Start Station Latitude         0
# Start Station Longitude        0
# End Station ID                 0
# End Station Name               0
# End Station Latitude           0
# End Station Longitude          0
# Bike ID                        0
# User Type                    380
# Birth Year                 18999
# Gender                         0
# dtype: int64

# %%
# User Type (Customer = 24-hour pass or 3-day pass user; Subscriber = Annual Member)
# Gender (Zero=unknown; 1=male; 2=female)

# ✅ rename columns to snake_type
bikes.columns = ['trip_duration', 'start_time', 'stop_time', 'start_station_id', 'start_station_name', 'start_station_lat', 'start_station_long', 'end_station_id','end_station_name' , 'end_station_lat', 'end_station_long', 'bike_id', 'user_type', 'birth_year', 'gender']

# ✅ replace 0, 1, 2 in gender column with the according labels
bikes.gender = bikes.gender.replace(1, 'male', regex=False)
bikes.gender = bikes.gender.replace(2, 'female', regex=False)
bikes.gender = bikes.gender.replace(0, np.nan, regex=False)

# ✅ change datatype to datetime
bikes.start_time = bikes.start_time.astype('datetime64[ns]')
bikes.stop_time = pd.to_datetime(bikes.stop_time)

bikes.head()
# Out:
#    trip_duration          start_time           stop_time  start_station_id  \
# 0            362 2016-01-01 00:02:52 2016-01-01 00:08:54              3186
# 1            200 2016-01-01 00:18:22 2016-01-01 00:21:42              3186
# 2            202 2016-01-01 00:18:25 2016-01-01 00:21:47              3186
# 3            248 2016-01-01 00:23:13 2016-01-01 00:27:21              3209
# 4            903 2016-01-01 01:03:20 2016-01-01 01:18:24              3195
#
#   start_station_name  start_station_lat  start_station_long  end_station_id  \
# 0      Grove St PATH          40.719586          -74.043117            3209
# 1      Grove St PATH          40.719586          -74.043117            3213
# 2      Grove St PATH          40.719586          -74.043117            3213
# 3       Brunswick St          40.724176          -74.050656            3203
# 4            Sip Ave          40.730743          -74.063784            3210
#
#   end_station_name  end_station_lat  end_station_long  bike_id   user_type  \
# 0     Brunswick St        40.724176        -74.050656    24647  Subscriber
# 1   Van Vorst Park        40.718489        -74.047727    24605  Subscriber
# 2   Van Vorst Park        40.718489        -74.047727    24689  Subscriber
# 3    Hamilton Park        40.727596        -74.044247    24693  Subscriber
# 4   Pershing Field        40.742677        -74.051789    24573    Customer
#
#    birth_year  gender
# 0      1964.0  female
# 1      1962.0    male
# 2      1962.0  female
# 3      1984.0    male
# 4         NaN     NaN

# %%
# ✅ make trip_duration an actual timedelta column for more comfortable data analysis
bikes.trip_duration = bikes.stop_time - bikes.start_time

bikes.head()
# Out:
#     trip_duration          start_time           stop_time  start_station_id  \
# 0 0 days 00:06:02 2016-01-01 00:02:52 2016-01-01 00:08:54              3186
# 1 0 days 00:03:20 2016-01-01 00:18:22 2016-01-01 00:21:42              3186
# 2 0 days 00:03:22 2016-01-01 00:18:25 2016-01-01 00:21:47              3186
# 3 0 days 00:04:08 2016-01-01 00:23:13 2016-01-01 00:27:21              3209
# 4 0 days 00:15:04 2016-01-01 01:03:20 2016-01-01 01:18:24              3195
#
#   start_station_name  start_station_lat  start_station_long  end_station_id  \
# 0      Grove St PATH          40.719586          -74.043117            3209
# 1      Grove St PATH          40.719586          -74.043117            3213
# 2      Grove St PATH          40.719586          -74.043117            3213
# 3       Brunswick St          40.724176          -74.050656            3203
# 4            Sip Ave          40.730743          -74.063784            3210
#
#   end_station_name  end_station_lat  end_station_long  bike_id   user_type  \
# 0     Brunswick St        40.724176        -74.050656    24647  Subscriber
# 1   Van Vorst Park        40.718489        -74.047727    24605  Subscriber
# 2   Van Vorst Park        40.718489        -74.047727    24689  Subscriber
# 3    Hamilton Park        40.727596        -74.044247    24693  Subscriber
# 4   Pershing Field        40.742677        -74.051789    24573    Customer
#
#    birth_year  gender
# 0      1964.0  female
# 1      1962.0    male
# 2      1962.0  female
# 3      1984.0    male
# 4         NaN     NaN

# %%
# ✅ check that all our columns are according dtype
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247584 entries, 0 to 247583
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_duration       247584 non-null  timedelta64[ns]
#  1   start_time          247584 non-null  datetime64[ns]
#  2   stop_time           247584 non-null  datetime64[ns]
#  3   start_station_id    247584 non-null  int64
#  4   start_station_name  247584 non-null  object
#  5   start_station_lat   247584 non-null  float64
#  6   start_station_long  247584 non-null  float64
#  7   end_station_id      247584 non-null  int64
#  8   end_station_name    247584 non-null  object
#  9   end_station_lat     247584 non-null  float64
#  10  end_station_long    247584 non-null  float64
#  11  bike_id             247584 non-null  int64
#  12  user_type           247204 non-null  object
#  13  birth_year          228585 non-null  float64
#  14  gender              227683 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(3), object(4), timedelta64[ns](1)
# memory usage: 28.3+ MB

# %%
# ✅ create Boolean columns for more comfortable analysis of columns where something is missing
bikes['missing_user_type'] = bikes.user_type.isna()
bikes['missing_birth_year'] = bikes.birth_year.isna()
bikes['missing_gender'] = bikes.gender.isna()

# bikes.head(15)

# %%
# ✅ create one Boolean column to show if there's anything missing (again for comfortable analysis)
bikes['has_missing'] = (
    (bikes.missing_user_type == True) |
    (bikes.missing_birth_year == True) |
    (bikes.missing_gender == True)
)

# ✅ another Boolean column to show if there's any implausible data (can add other things if found later as well). Usually 1900 is a placeholder year of birth
bikes['has_bad'] = (
    (bikes.birth_year <= 1900) |
    (bikes.trip_duration <= '00:00:00') |
    (bikes.trip_duration >= '00:45:00')
)

# ✅ calculating age in a separate column
bikes['age'] = 2016 - bikes.birth_year

# ✅ check final result
bikes
# Out:
#          trip_duration          start_time           stop_time  \
# 0      0 days 00:06:02 2016-01-01 00:02:52 2016-01-01 00:08:54
# 1      0 days 00:03:20 2016-01-01 00:18:22 2016-01-01 00:21:42
# 2      0 days 00:03:22 2016-01-01 00:18:25 2016-01-01 00:21:47
# 3      0 days 00:04:08 2016-01-01 00:23:13 2016-01-01 00:27:21
# 4      0 days 00:15:04 2016-01-01 01:03:20 2016-01-01 01:18:24
# ...                ...                 ...                 ...
# 247579 0 days 00:09:17 2016-12-31 23:10:16 2016-12-31 23:19:33
# 247580 0 days 00:45:50 2016-12-31 23:29:39 2017-01-01 00:15:29
# 247581 0 days 00:02:54 2016-12-31 23:44:37 2016-12-31 23:47:31
# 247582 0 days 00:40:24 2016-12-31 23:44:50 2017-01-01 00:25:14
# 247583 0 days 00:40:20 2016-12-31 23:44:50 2017-01-01 00:25:10
#
#         start_station_id start_station_name  start_station_lat  \
# 0                   3186      Grove St PATH          40.719586
# 1                   3186      Grove St PATH          40.719586
# 2                   3186      Grove St PATH          40.719586
# 3                   3209       Brunswick St          40.724176
# 4                   3195            Sip Ave          40.730743
# ...                  ...                ...                ...
# 247579              3214   Essex Light Rail          40.712774
# 247580              3183     Exchange Place          40.716247
# 247581              3186      Grove St PATH          40.719586
# 247582              3214   Essex Light Rail          40.712774
# 247583              3214   Essex Light Rail          40.712774
#
#         start_station_long  end_station_id  end_station_name  end_station_lat  \
# 0               -74.043117            3209      Brunswick St        40.724176
# 1               -74.043117            3213    Van Vorst Park        40.718489
# 2               -74.043117            3213    Van Vorst Park        40.718489
# 3               -74.050656            3203     Hamilton Park        40.727596
# 4               -74.063784            3210    Pershing Field        40.742677
# ...                    ...             ...               ...              ...
# 247579          -74.036486            3203     Hamilton Park        40.727596
# 247580          -74.033459            3183    Exchange Place        40.716247
# 247581          -74.043117            3270   Jersey & 6th St        40.725289
# 247582          -74.036486            3214  Essex Light Rail        40.712774
# 247583          -74.036486            3214  Essex Light Rail        40.712774
#
#         ...  bike_id   user_type birth_year  gender missing_user_type  \
# 0       ...    24647  Subscriber     1964.0  female             False
# 1       ...    24605  Subscriber     1962.0    male             False
# 2       ...    24689  Subscriber     1962.0  female             False
# 3       ...    24693  Subscriber     1984.0    male             False
# 4       ...    24573    Customer        NaN     NaN             False
# ...     ...      ...         ...        ...     ...               ...
# 247579  ...    24465  Subscriber     1981.0  female             False
# 247580  ...    24389    Customer        NaN     NaN             False
# 247581  ...    24641  Subscriber     1978.0    male             False
# 247582  ...    26219  Subscriber     1960.0  female             False
# 247583  ...    24471  Subscriber     1956.0    male             False
#
#         missing_birth_year  missing_gender  has_missing  has_bad   age
# 0                    False           False        False    False  52.0
# 1                    False           False        False    False  54.0
# 2                    False           False        False    False  54.0
# 3                    False           False        False    False  32.0
# 4                     True            True         True    False   NaN
# ...                    ...             ...          ...      ...   ...
# 247579               False           False        False    False  35.0
# 247580                True            True         True     True   NaN
# 247581               False           False        False    False  38.0
# 247582               False           False        False    False  56.0
# 247583               False           False        False    False  60.0
#
# [247584 rows x 21 columns]

# %%
# ✅ last bit with descriptive statistics
bikes.describe()
# Out:
#                    trip_duration                     start_time  \
# count                     247584                         247584
# mean   0 days 00:14:46.129737785  2016-07-29 05:55:07.541335040
# min            -1 days +23:05:29            2016-01-01 00:02:52
# 25%              0 days 00:04:09            2016-05-27 07:46:06
# 50%              0 days 00:06:30            2016-08-10 09:23:50
# 75%              0 days 00:11:07     2016-10-05 17:25:05.500000
# max            189 days 00:03:28            2016-12-31 23:44:50
# std    0 days 09:58:58.104602902                            NaN
#
#                            stop_time  start_station_id  start_station_lat  \
# count                         247584     247584.000000      247584.000000
# mean   2016-07-29 06:09:53.671073536       3207.065206          40.723121
# min              2016-01-01 00:08:54       3183.000000          40.692640
# 25%    2016-05-27 07:54:40.249999872       3186.000000          40.717732
# 50%       2016-08-10 09:34:32.500000       3201.000000          40.721525
# 75%    2016-10-05 17:33:00.750000128       3211.000000          40.727596
# max              2017-01-18 14:26:46       3426.000000          40.752559
# std                              NaN         26.955103           0.008199
#
#        start_station_long  end_station_id  end_station_lat  end_station_long  \
# count       247584.000000   247584.000000    247584.000000     247584.000000
# mean           -74.046438     3203.572553        40.722594        -74.045855
# min            -74.096937      147.000000        40.692216        -74.096937
# 25%            -74.050656     3186.000000        40.716540        -74.050444
# 50%            -74.044247     3199.000000        40.721124        -74.043117
# 75%            -74.038051     3211.000000        40.727224        -74.036486
# max            -74.032108     3426.000000        40.801343        -73.957390
# std              0.011211       61.579494         0.007958          0.011283
#
#              bike_id     birth_year            age
# count  247584.000000  228585.000000  228585.000000
# mean    24935.260481    1979.335276      36.664724
# min     14552.000000    1900.000000      16.000000
# 25%     24491.000000    1974.000000      30.000000
# 50%     24609.000000    1981.000000      35.000000
# 75%     24719.000000    1986.000000      42.000000
# max     27274.000000    2000.000000     116.000000
# std       748.469712       9.596809       9.596809

# %%
# ✅ check all the bad data
has_bad_data = bikes[bikes.has_bad == True]
has_bad_data
# Out:
#          trip_duration          start_time           stop_time  \
# 53     0 days 00:51:31 2016-01-01 11:07:15 2016-01-01 11:58:46
# 68     0 days 00:49:17 2016-01-01 13:09:23 2016-01-01 13:58:40
# 99     0 days 01:09:48 2016-01-01 15:24:16 2016-01-01 16:34:04
# 104    0 days 00:49:40 2016-01-01 15:41:34 2016-01-01 16:31:14
# 229    0 days 01:05:40 2016-01-02 12:32:42 2016-01-02 13:38:22
# ...                ...                 ...                 ...
# 247424 0 days 01:57:55 2016-12-31 13:41:43 2016-12-31 15:39:38
# 247441 0 days 00:46:47 2016-12-31 14:30:46 2016-12-31 15:17:33
# 247443 0 days 22:07:49 2016-12-31 14:35:25 2017-01-01 12:43:14
# 247508 0 days 01:12:46 2016-12-31 16:51:39 2016-12-31 18:04:25
# 247580 0 days 00:45:50 2016-12-31 23:29:39 2017-01-01 00:15:29
#
#         start_station_id start_station_name  start_station_lat  \
# 53                  3203      Hamilton Park          40.727596
# 68                  3199       Newport Pkwy          40.728745
# 99                  3213     Van Vorst Park          40.718489
# 104                 3187          Warren St          40.721124
# 229                 3184        Paulus Hook          40.714145
# ...                  ...                ...                ...
# 247424              3185          City Hall          40.717732
# 247441              3183     Exchange Place          40.716247
# 247443              3275     Columbus Drive          40.718355
# 247508              3198   Heights Elevator          40.748716
# 247580              3183     Exchange Place          40.716247
#
#         start_station_long  end_station_id end_station_name  end_station_lat  \
# 53              -74.044247            3203    Hamilton Park        40.727596
# 68              -74.032108            3199     Newport Pkwy        40.728745
# 99              -74.047727            3213   Van Vorst Park        40.718489
# 104             -74.038051            3187        Warren St        40.721124
# 229             -74.033552            3184      Paulus Hook        40.714145
# ...                    ...             ...              ...              ...
# 247424          -74.043845            3213   Van Vorst Park        40.718489
# 247441          -74.033459            3272     Jersey & 3rd        40.723332
# 247443          -74.038914            3199     Newport Pkwy        40.728745
# 247508          -74.040443            3202     Newport PATH        40.727224
# 247580          -74.033459            3183   Exchange Place        40.716247
#
#         ...  bike_id   user_type birth_year  gender missing_user_type  \
# 53      ...    24444    Customer        NaN     NaN             False
# 68      ...    24609  Subscriber     1978.0    male             False
# 99      ...    24427  Subscriber     1968.0  female             False
# 104     ...    24605  Subscriber     1992.0    male             False
# 229     ...    24656  Subscriber     1975.0  female             False
# ...     ...      ...         ...        ...     ...               ...
# 247424  ...    24513    Customer        NaN     NaN             False
# 247441  ...    26167  Subscriber     1954.0  female             False
# 247443  ...    26217    Customer        NaN     NaN             False
# 247508  ...    26178  Subscriber     1954.0  female             False
# 247580  ...    24389    Customer        NaN     NaN             False
#
#         missing_birth_year  missing_gender  has_missing  has_bad   age
# 53                    True            True         True     True   NaN
# 68                   False           False        False     True  38.0
# 99                   False           False        False     True  48.0
# 104                  False           False        False     True  24.0
# 229                  False           False        False     True  41.0
# ...                    ...             ...          ...      ...   ...
# 247424                True            True         True     True   NaN
# 247441               False           False        False     True  62.0
# 247443                True            True         True     True   NaN
# 247508               False           False        False     True  62.0
# 247580                True            True         True     True   NaN
#
# [4767 rows x 21 columns]

# %%
# ✅ and all the data that somewhere is empty or incomplete
has_empty = bikes[bikes.has_missing == True]
has_empty
# Out:
#          trip_duration          start_time           stop_time  \
# 4      0 days 00:15:04 2016-01-01 01:03:20 2016-01-01 01:18:24
# 5      0 days 00:14:43 2016-01-01 01:03:28 2016-01-01 01:18:11
# 22     0 days 00:16:29 2016-01-01 03:16:33 2016-01-01 03:33:02
# 53     0 days 00:51:31 2016-01-01 11:07:15 2016-01-01 11:58:46
# 57     0 days 00:13:09 2016-01-01 11:50:30 2016-01-01 12:03:39
# ...                ...                 ...                 ...
# 247442 0 days 00:41:25 2016-12-31 14:35:19 2016-12-31 15:16:44
# 247443 0 days 22:07:49 2016-12-31 14:35:25 2017-01-01 12:43:14
# 247537 0 days 00:03:45 2016-12-31 18:01:38 2016-12-31 18:05:23
# 247561 0 days 00:07:21 2016-12-31 20:12:26 2016-12-31 20:19:47
# 247580 0 days 00:45:50 2016-12-31 23:29:39 2017-01-01 00:15:29
#
#         start_station_id start_station_name  start_station_lat  \
# 4                   3195            Sip Ave          40.730743
# 5                   3195            Sip Ave          40.730743
# 22                  3196     Riverview Park          40.744319
# 53                  3203      Hamilton Park          40.727596
# 57                  3210     Pershing Field          40.742677
# ...                  ...                ...                ...
# 247442              3275     Columbus Drive          40.718355
# 247443              3275     Columbus Drive          40.718355
# 247537              3194    McGinley Square          40.725340
# 247561              3195            Sip Ave          40.730743
# 247580              3183     Exchange Place          40.716247
#
#         start_station_long  end_station_id end_station_name  end_station_lat  \
# 4               -74.063784            3210   Pershing Field        40.742677
# 5               -74.063784            3210   Pershing Field        40.742677
# 22              -74.043991            3209     Brunswick St        40.724176
# 53              -74.044247            3203    Hamilton Park        40.727596
# 57              -74.051789            3195          Sip Ave        40.730743
# ...                    ...             ...              ...              ...
# 247442          -74.038914            3199     Newport Pkwy        40.728745
# 247443          -74.038914            3199     Newport Pkwy        40.728745
# 247537          -74.067622            3195          Sip Ave        40.730743
# 247561          -74.063784            3193     Lincoln Park        40.724605
# 247580          -74.033459            3183   Exchange Place        40.716247
#
#         ...  bike_id   user_type birth_year  gender missing_user_type  \
# 4       ...    24573    Customer        NaN     NaN             False
# 5       ...    24442    Customer        NaN     NaN             False
# 22      ...    24662    Customer        NaN     NaN             False
# 53      ...    24444    Customer        NaN     NaN             False
# 57      ...    24573    Customer        NaN     NaN             False
# ...     ...      ...         ...        ...     ...               ...
# 247442  ...    24627    Customer        NaN     NaN             False
# 247443  ...    26217    Customer        NaN     NaN             False
# 247537  ...    24716  Subscriber        NaN     NaN             False
# 247561  ...    24417  Subscriber        NaN     NaN             False
# 247580  ...    24389    Customer        NaN     NaN             False
#
#         missing_birth_year  missing_gender  has_missing  has_bad  age
# 4                     True            True         True    False  NaN
# 5                     True            True         True    False  NaN
# 22                    True            True         True    False  NaN
# 53                    True            True         True     True  NaN
# 57                    True            True         True    False  NaN
# ...                    ...             ...          ...      ...  ...
# 247442                True            True         True    False  NaN
# 247443                True            True         True     True  NaN
# 247537                True            True         True    False  NaN
# 247561                True            True         True    False  NaN
# 247580                True            True         True     True  NaN
#
# [20281 rows x 21 columns]

# %%
# ✅ see the clean data without any missing data and outliers
clean_df = bikes[(~bikes.has_missing & ~bikes.has_bad)]

clean_df.describe()
# Out:
#                    trip_duration                     start_time  \
# count                     225097                         225097
# mean   0 days 00:08:21.385549340  2016-07-29 14:47:54.159202304
# min              0 days 00:01:01            2016-01-01 00:02:52
# 25%              0 days 00:04:01            2016-05-26 17:32:53
# 50%              0 days 00:06:07            2016-08-10 21:24:59
# 75%              0 days 00:10:01            2016-10-06 21:22:10
# max              0 days 00:44:59            2016-12-31 23:44:50
# std    0 days 00:06:53.652273025                            NaN
#
#                            stop_time  start_station_id  start_station_lat  \
# count                         225097     225097.000000      225097.000000
# mean   2016-07-29 14:56:15.544751872       3207.190998          40.723291
# min              2016-01-01 00:08:54       3183.000000          40.692640
# 25%              2016-05-26 17:45:01       3186.000000          40.717732
# 50%              2016-08-10 21:38:06       3202.000000          40.721525
# 75%              2016-10-06 21:29:53       3211.000000          40.727596
# max              2017-01-01 00:25:14       3426.000000          40.752559
# std                              NaN         27.017247           0.008129
#
#        start_station_long  end_station_id  end_station_lat  end_station_long  \
# count       225097.000000   225097.000000    225097.000000     225097.000000
# mean           -74.046609     3204.029894        40.722723        -74.046005
# min            -74.096937      173.000000        40.692216        -74.096937
# 25%            -74.050656     3186.000000        40.717732        -74.050444
# 50%            -74.044247     3198.000000        40.721124        -74.043845
# 75%            -74.038051     3211.000000        40.727224        -74.038051
# max            -74.032108     3426.000000        40.760875        -73.971212
# std              0.011173       50.726917         0.007865          0.011227
#
#              bike_id     birth_year            age
# count  225097.000000  225097.000000  225097.000000
# mean    24938.594246    1979.329942      36.670058
# min     14552.000000    1934.000000      16.000000
# 25%     24491.000000    1974.000000      30.000000
# 50%     24611.000000    1981.000000      35.000000
# 75%     24719.000000    1986.000000      42.000000
# max     27274.000000    2000.000000      82.000000
# std       750.121291       9.590069       9.590069

# %%
bikes.to_csv('citibike_2016_cleaned.csv')
